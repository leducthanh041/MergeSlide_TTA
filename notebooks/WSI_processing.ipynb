# %% [markdown]
# ## **0. Clone PrePath**

# %%
# !git clone https://github.com/birkhoffkiki/PrePATH
# Out:
# Cloning into 'PrePATH'...
# remote: Enumerating objects: 628, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 628 (delta 169), reused 191 (delta 122), pack-reused 364 (from 1)
# Receiving objects: 100% (628/628), 13.25 MiB | 8.99 MiB/s, done.
# Resolving deltas: 100% (334/334), done.

# %% [markdown]
# ### 0.1 Library Installation

# %%
# %cd /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH
# Out:
# /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH

# %%
# !pip install torch==2.3.0 \
# torchvision==0.18.0 \
# timm==1.0.15 \
# wandb \
# openslide-python \
# openslide-bin h5py==3.8.0 \
# numpy==1.26.4 \
# opencv_python==4.7.0.72 \
# opencv_python_headless==4.10.0.84 \
# paramiko==3.5.1 \
# pathos==0.3.3 \
# Pillow==11.2.1 \
# PyYAML==6.0.2 \
# scipy==1.15.3 \
# scp==0.15.0 \
# setuptools==65.6.3 \
# pandas einops_exts

# %% [markdown]
# ## **1. Download WSIs from GDC client**

# %% [markdown]
# ### 1.1. Prepare directory to download data from GDC client

# %%
# !mkdir downloaded_data

# %%
# %cd downloaded_data
# Out:
# /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH/downloaded_data

# %%
# !mkdir TCGA-BRCA

# %%
# %cd TCGA-BRCA

# %%
# !gdown --id 1dsu9Drmeme5Of3EKt0KBAQOyEUfU84gv

# %%
# !chmod 777 ./gdc-client

# %%
# !./gdc-client download -m ./gdc_manifest.2025-10-20.154101.txt

# %%
# %cd /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH
# Out:
# /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH

# %% [markdown]
# ### 2.1. WSI patching

# %% [markdown]
# ![{68D7FA8F-A72F-4F3B-B9C2-0AD99DC421F8}.png](data:image/png;base64,...)

# %% [markdown]
# Note: Fix line 139 in `create_patches_fp.py`:
# ```
# full_path = os.path.join(slide)
# ```

# %%
# The coordinates of the patches are saved, you can change the path to any directory you want.
save_dir="./downloaded_data/CESC_patches"
# The directory where the WSI files are stored, you can change it to any directory you want.
wsi_dir="/datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946"
# The WSI format, you can set it based on the format of your WSI
wsi_format="svs" # .tiff, .svs
# The log file name, you can change it to any name you want.
log_name="CESC.log"

# Normally, you don't need to change following lines.
# to set the patch size, please set it at `configs/resolution.py`
# 0: 40x, 1: 10x, 2: 5x, 4: 2.5x
# !python create_patches_fp.py \
        --source $wsi_dir \
        --save_dir $save_dir --preset tcga.csv \
        --patch_level 1 \
        --wsi_format $wsi_format \
        --seg \
        --patch \
        --stitch
# Out:
# source:  /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946
# patch_save_dir:  ./downloaded_data/CESC_patches/patches
# mask_save_dir:  ./downloaded_data/CESC_patches/masks
# stitch_save_dir:  ./downloaded_data/CESC_patches/stitches
# source : /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946
# save_dir : ./downloaded_data/CESC_patches
# patch_save_dir : ./downloaded_data/CESC_patches/patches
# mask_save_dir : ./downloaded_data/CESC_patches/masks
# stitch_save_dir : ./downloaded_data/CESC_patches/stitches
# {'seg_params': {'seg_level': -1, 'sthresh': 8, 'mthresh': 7, 'close': 4, 'use_otsu': True, 'keep_ids': 'none', 'exclude_ids': 'none'}, 'filter_params': {'a_t': 16, 'a_h': 4, 'max_n_holes': 8}, 'patch_params': {'use_padding': True, 'contour_fn': 'four_pt'}, 'vis_params': {'vis_level': -1, 'line_thickness': 100}}
# {'source': '/datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946', 'save_dir': './downloaded_data/CESC_patches', 'patch_save_dir': './downloaded_data/CESC_patches/patches', 'mask_save_dir': './downloaded_data/CESC_patches/masks', 'stitch_save_dir': './downloaded_data/CESC_patches/stitches'}
# Total: 604
#
#
# progress: 0.00, 0/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/0297988d-fb09-4aa1-9b9c-9a60fc913fa0/TCGA-C5-A7X5-01Z-00-DX1.C1E65119-AF9B-457E-8864-17A782BBC9D2.svs
# ####################################################################################################
# levels: ((131520, 30341), (32880, 7585), (8220, 1896), (2055, 474))
# mpp: 0.250, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A7X5-01Z-00-DX1.C1E65119-AF9B-457E-8864-17A782BBC9D2 ...
# Total number of contours to process:  16
# Bounding Box: 47232 19139 3649 3937
# Contour Area: 6935552.0
# Extracted 11 coordinates
# Bounding Box: 86912 18883 3617 3793
# Contour Area: 6646144.0
# Extracted 11 coordinates
# Bounding Box: 9008 16786 3953 4258
# Contour Area: 7006048.0
# Extracted 11 coordinates
# Bounding Box: 126592 16594 3601 3698
# Contour Area: 6473240.0
# Extracted 11 coordinates
# Bounding Box: 77872 16034 10721 11507
# Contour Area: 64928712.0
# Extracted 80 coordinates
# Bounding Box: 37968 16018 10721 11635
# Contour Area: 65928776.0
# Extracted 78 coordinates
# Bounding Box: 117552 14034 10849 11459
# Contour Area: 64418208.0
# Extracted 76 coordinates
# Bounding Box: 0 13186 10097 11715
# Contour Area: 64686360.0
# Extracted 78 coordinates
# Bounding Box: 82416 9569 5057 5698
# Contour Area: 16884200.0
# Extracted 25 coordinates
# Bounding Box: 43184 9473 5185 6018
# Contour Area: 17824736.0
# Extracted 23 coordinates
# Bounding Box: 121616 7505 5073 5490
# Contour Area: 15869840.0
# Extracted 25 coordinates
# Bounding Box: 6096 6913 5425 6274
# Contour Area: 17376496.0
# Extracted 24 coordinates
# Bounding Box: 80048 3904 3601 9587
# Contour Area: 15488840.0
# Extracted 24 coordinates
# Bounding Box: 40848 3888 3953 9603
# Contour Area: 16357080.0
# Extracted 23 coordinates
# Bounding Box: 119152 1904 3249 9538
# Contour Area: 14798328.0
# Extracted 22 coordinates
# Bounding Box: 4048 1440 4433 9346
# Contour Area: 15927976.0
# Extracted 21 coordinates
# start stitching TCGA-C5-A7X5-01Z-00-DX1.C1E65119-AF9B-457E-8864-17A782BBC9D2
# original size: 131520 x 30341
# downscaled size for stiching: 8220 x 1896
# number of patches: 543
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 64x64
# progress: 0/543 stitched
# progress: 55/543 stitched
# progress: 110/543 stitched
# progress: 165/543 stitched
# progress: 220/543 stitched
# progress: 275/543 stitched
# progress: 330/543 stitched
# progress: 385/543 stitched
# progress: 440/543 stitched
# progress: 495/543 stitched
# segmentation took 3.676252841949463 seconds
# patching took 1.3806273937225342 seconds
# stitching took 0.9459712505340576 seconds
#
#
# progress: 0.00, 1/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/789f5e3f-7b59-40f6-9d47-7dfb31201815/TCGA-EA-A5FO-01Z-00-DX1.202FDE15-12C5-4AA6-B431-213BA1551866.svs
# ####################################################################################################
# levels: ((78064, 49442), (19516, 12360), (4879, 3090), (2439, 1545))
# mpp: 0.246, base_power: 41x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.25x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-EA-A5FO-01Z-00-DX1.202FDE15-12C5-4AA6-B431-213BA1551866 ...
# Total number of contours to process:  2
# Bounding Box: 73487 12512 2337 2849
# Contour Area: 4203008.0
# Extracted 7 coordinates
# Bounding Box: 1632 2144 72592 44610
# Contour Area: 2012283422.0
# Extracted 2024 coordinates
# start stitching TCGA-EA-A5FO-01Z-00-DX1.202FDE15-12C5-4AA6-B431-213BA1551866
# original size: 78064 x 49442
# downscaled size for stiching: 2439 x 1545
# number of patches: 2031
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/2031 stitched
# progress: 204/2031 stitched
# progress: 408/2031 stitched
# progress: 612/2031 stitched
# progress: 816/2031 stitched
# progress: 1020/2031 stitched
# progress: 1224/2031 stitched
# progress: 1428/2031 stitched
# progress: 1632/2031 stitched
# progress: 1836/2031 stitched
# segmentation took 5.014579772949219 seconds
# patching took 0.3559262752532959 seconds
# stitching took 2.5854432582855225 seconds
#
#
# progress: 0.00, 2/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/89fb2c28-2eba-406c-a687-385e8ccfc468/TCGA-VS-A9V2-01A-01-TS1.84BB47F0-6ECC-4C57-BBFF-7A833624E45E.svs
# ####################################################################################################
# levels: ((83664, 27885), (20916, 6971), (5229, 1742), (2614, 871))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-VS-A9V2-01A-01-TS1.84BB47F0-6ECC-4C57-BBFF-7A833624E45E ...
# Total number of contours to process:  2
# Bounding Box: 4032 6178 18725 17674
# Contour Area: 241898711.5
# Extracted 250 coordinates
# Bounding Box: 59819 3873 21061 17834
# Contour Area: 275596650.0
# Extracted 283 coordinates
# start stitching TCGA-VS-A9V2-01A-01-TS1.84BB47F0-6ECC-4C57-BBFF-7A833624E45E
# original size: 83664 x 27885
# downscaled size for stiching: 2614 x 871
# number of patches: 533
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/533 stitched
# progress: 54/533 stitched
# progress: 108/533 stitched
# progress: 162/533 stitched
# progress: 216/533 stitched
# progress: 270/533 stitched
# progress: 324/533 stitched
# progress: 378/533 stitched
# progress: 432/533 stitched
# progress: 486/533 stitched
# segmentation took 0.22156715393066406 seconds
# patching took 0.21530842781066895 seconds
# stitching took 0.16354632377624512 seconds
#
#
# progress: 0.00, 3/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/db72caba-f574-44f1-b47f-304033cd1d41/TCGA-VS-A8EJ-01A-01-TS1.06EAF8F3-2A82-493E-9557-F29733942DE1.svs
# ####################################################################################################
# levels: ((105575, 31167), (26393, 7791), (6598, 1947), (3299, 973))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-VS-A8EJ-01A-01-TS1.06EAF8F3-2A82-493E-9557-F29733942DE1 ...
# Total number of contours to process:  2
# Bounding Box: 6816 6598 21922 21879
# Contour Area: 319439651.0
# Extracted 334 coordinates
# Bounding Box: 72516 1793 22819 21495
# Contour Area: 331141247.5
# Extracted 330 coordinates
# start stitching TCGA-VS-A8EJ-01A-01-TS1.06EAF8F3-2A82-493E-9557-F29733942DE1
# original size: 105575 x 31167
# downscaled size for stiching: 3299 x 973
# number of patches: 664
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/664 stitched
# progress: 67/664 stitched
# progress: 134/664 stitched
# progress: 201/664 stitched
# progress: 268/664 stitched
# progress: 335/664 stitched
# progress: 402/664 stitched
# progress: 469/664 stitched
# progress: 536/664 stitched
# progress: 603/664 stitched
# segmentation took 0.3398008346557617 seconds
# patching took 0.21783781051635742 seconds
# stitching took 0.20809078216552734 seconds
#
#
# progress: 0.01, 4/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/45c871dd-68b9-4a89-bda4-a3be23d6d049/TCGA-VS-A8Q8-01Z-00-DX1.F47487F3-799F-4701-A066-8167E41F78C9.svs
# ####################################################################################################
# levels: ((107568, 80833), (26892, 20208), (6723, 5052), (3361, 2526))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-VS-A8Q8-01Z-00-DX1.F47487F3-799F-4701-A066-8167E41F78C9 ...
# Total number of contours to process:  3
# Bounding Box: 93453 49856 10947 24449
# Contour Area: 108714128.0
# Extracted 132 coordinates
# Bounding Box: 91757 46528 3778 7105
# Contour Area: 10892432.0
# Extracted 16 coordinates
# Bounding Box: 4320 5088 94511 74593
# Contour Area: 4291341440.0
# Extracted 4221 coordinates
# start stitching TCGA-VS-A8Q8-01Z-00-DX1.F47487F3-799F-4701-A066-8167E41F78C9
# original size: 107568 x 80833
# downscaled size for stiching: 3361 x 2526
# number of patches: 4369
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/4369 stitched
# progress: 437/4369 stitched
# progress: 874/4369 stitched
# progress: 1311/4369 stitched
# progress: 1748/4369 stitched
# progress: 2185/4369 stitched
# progress: 2622/4369 stitched
# progress: 3059/4369 stitched
# progress: 3496/4369 stitched
# progress: 3933/4369 stitched
# segmentation took 1.1967346668243408 seconds
# patching took 0.5982859134674072 seconds
# stitching took 1.5603222846984863 seconds
#
#
# progress: 0.01, 5/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/a0fa3578-6104-4309-84b1-ec865e90e0f8/TCGA-DS-A1OA-01A-01-TSA.36e29ed6-b98a-4db7-beb7-a1f1e95960ab.svs
# ####################################################################################################
# levels: ((87583, 29422), (21895, 7355), (5473, 1838), (2736, 919))
# mpp: 0.248, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-DS-A1OA-01A-01-TSA.36e29ed6-b98a-4db7-beb7-a1f1e95960ab ...
# Total number of contours to process:  9
# Bounding Box: 15845 18408 11781 2338
# Contour Area: 13257826.0
# Extracted 16 coordinates
# Bounding Box: 69784 18280 6275 1858
# Contour Area: 6378194.0
# Extracted 10 coordinates
# Bounding Box: 66967 10853 4579 6948
# Contour Area: 14597746.0
# Extracted 22 coordinates
# Bounding Box: 23272 10116 5891 9670
# Contour Area: 30336549.0
# Extracted 37 coordinates
# Bounding Box: 59893 8387 1793 4836
# Contour Area: 4662064.0
# Extracted 8 coordinates
# Bounding Box: 73209 8099 7012 11943
# Contour Area: 41374777.0
# Extracted 51 coordinates
# Bounding Box: 53715 7523 4546 13608
# Contour Area: 31466899.0
# Extracted 40 coordinates
# Bounding Box: 57908 5250 3266 4323
# Contour Area: 7739234.0
# Extracted 10 coordinates
# Bounding Box: 3233 5090 22024 15752
# Contour Area: 125158776.0
# Extracted 152 coordinates
# start stitching TCGA-DS-A1OA-01A-01-TSA.36e29ed6-b98a-4db7-beb7-a1f1e95960ab
# original size: 87583 x 29422
# downscaled size for stiching: 2736 x 919
# number of patches: 346
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/346 stitched
# progress: 35/346 stitched
# progress: 70/346 stitched
# progress: 105/346 stitched
# progress: 140/346 stitched
# progress: 175/346 stitched
# progress: 210/346 stitched
# progress: 245/346 stitched
# progress: 280/346 stitched
# progress: 315/346 stitched
# segmentation took 0.28273725509643555 seconds
# patching took 0.8021371364593506 seconds
# stitching took 0.12183713912963867 seconds
#
#
# progress: 0.01, 6/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/02e2c024-b7bc-4c3b-b41b-2f7d56675437/TCGA-EX-A1H6-01Z-00-DX1.C7BFF24E-B6DD-41D9-BACF-CE64989FC10A.svs
# ####################################################################################################
# levels: ((69719, 34675), (17429, 8668), (4357, 2167), (2178, 1083))
# mpp: 0.494, base_power: 20x, patch_level: 1, patch_downsample: 4.00, patch_power: 5.00x, profile: 5x, patch_size: 512, step_size: 512
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-EX-A1H6-01Z-00-DX1.C7BFF24E-B6DD-41D9-BACF-CE64989FC10A ...
# Total number of contours to process:  4
# Bounding Box: 21511 22636 3234 3619
# Contour Area: 7805969.0
# Extracted 4 coordinates
# Bounding Box: 65557 18089 3298 3523
# Contour Area: 7541394.0
# Extracted 4 coordinates
# Bounding Box: 640 5250 25705 28145
# Contour Area: 432369037.0
# Extracted 119 coordinates
# Bounding Box: 44078 1216 25609 28369
# Contour Area: 433078463.0
# Extracted 118 coordinates
# start stitching TCGA-EX-A1H6-01Z-00-DX1.C7BFF24E-B6DD-41D9-BACF-CE64989FC10A
# original size: 69719 x 34675
# downscaled size for stiching: 2178 x 1083
# number of patches: 245
# patch size: 512x512 patch level: 1
# ref patch size: (2048, 2048)x(2048, 2048)
# downscaled patch size: 64x64
# progress: 0/245 stitched
# progress: 25/245 stitched
# progress: 50/245 stitched
# progress: 75/245 stitched
# progress: 100/245 stitched
# progress: 125/245 stitched
# progress: 150/245 stitched
# progress: 175/245 stitched
# progress: 200/245 stitched
# progress: 225/245 stitched
# segmentation took 0.27228546142578125 seconds
# patching took 0.3717679977416992 seconds
# stitching took 0.20437026023864746 seconds
#
#
# progress: 0.01, 7/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/cf2067f9-9509-41f6-8abb-a50e35c4084b/TCGA-C5-A2M2-01Z-00-DX1.145589C8-870A-49BD-BC54-A8951E2DEDE3.svs
# ####################################################################################################
# levels: ((115200, 88202), (28800, 22050), (7200, 5512), (3600, 2756))
# mpp: 0.250, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A2M2-01Z-00-DX1.145589C8-870A-49BD-BC54-A8951E2DEDE3 ...
# Total number of contours to process:  21
# Bounding Box: 44512 75272 7457 5666
# Contour Area: 30419184.0
# Extracted 34 coordinates
# Bounding Box: 13856 62279 41377 25891
# Contour Area: 494193584.0
# Extracted 533 coordinates
# Bounding Box: 25248 57606 9057 8706
# Contour Area: 47354912.0
# Extracted 56 coordinates
# Bounding Box: 15840 54822 4961 6689
# Contour Area: 12560384.0
# Extracted 20 coordinates
# Bounding Box: 77760 49061 3937 2689
# Contour Area: 4838912.0
# Extracted 7 coordinates
# Bounding Box: 38304 44613 48865 42565
# Contour Area: 1042970656.0
# Extracted 1098 coordinates
# Bounding Box: 48256 43396 9153 4258
# Contour Area: 25133472.0
# Extracted 31 coordinates
# Bounding Box: 9728 38372 2369 4321
# Contour Area: 5149184.0
# Extracted 7 coordinates
# Bounding Box: 44768 28803 9921 15106
# Contour Area: 90662752.0
# Extracted 96 coordinates
# Bounding Box: 15840 28259 28257 30756
# Contour Area: 389404256.0
# Extracted 432 coordinates
# Bounding Box: 83552 26787 2913 5697
# Contour Area: 9833984.0
# Extracted 14 coordinates
# Bounding Box: 53088 26178 22625 26116
# Contour Area: 330686560.0
# Extracted 313 coordinates
# Bounding Box: 50368 25218 3937 3138
# Contour Area: 5115168.0
# Extracted 9 coordinates
# Bounding Box: 66176 15905 20833 33157
# Contour Area: 288495760.0
# Extracted 326 coordinates
# Bounding Box: 32352 15809 3169 4866
# Contour Area: 9745824.0
# Extracted 13 coordinates
# Bounding Box: 37760 15329 13217 14019
# Contour Area: 108108656.0
# Extracted 107 coordinates
# Bounding Box: 85792 14753 17569 35717
# Contour Area: 325644816.0
# Extracted 353 coordinates
# Bounding Box: 103456 14241 4961 3970
# Contour Area: 10246256.0
# Extracted 15 coordinates
# Bounding Box: 10848 11041 16577 12450
# Contour Area: 82771040.0
# Extracted 102 coordinates
# Bounding Box: 58688 6144 15777 14787
# Contour Area: 133896784.0
# Extracted 148 coordinates
# Bounding Box: 68928 128 26369 22179
# Contour Area: 265516112.0
# Extracted 274 coordinates
# start stitching TCGA-C5-A2M2-01Z-00-DX1.145589C8-870A-49BD-BC54-A8951E2DEDE3
# original size: 115200 x 88202
# downscaled size for stiching: 3600 x 2756
# number of patches: 3988
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/3988 stitched
# progress: 399/3988 stitched
# progress: 798/3988 stitched
# progress: 1197/3988 stitched
# progress: 1596/3988 stitched
# progress: 1995/3988 stitched
# progress: 2394/3988 stitched
# progress: 2793/3988 stitched
# progress: 3192/3988 stitched
# progress: 3591/3988 stitched
# segmentation took 1.499565601348877 seconds
# patching took 2.2906367778778076 seconds
# stitching took 1.5753059387207031 seconds
#
#
# progress: 0.01, 8/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/fcc0f127-7a39-4fad-b0cc-85a6fa437f39/TCGA-C5-A2LT-01A-01-TSA.6E7DE933-623C-41F5-8007-4EAB8DB691B1.svs
# ####################################################################################################
# levels: ((72352, 17181), (18088, 4295), (4522, 1073), (2261, 536))
# mpp: 0.246, base_power: 41x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.25x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A2LT-01A-01-TSA.6E7DE933-623C-41F5-8007-4EAB8DB691B1 ...
# Total number of contours to process:  3
# Bounding Box: 62176 8975 7521 2565
# Contour Area: 8889120.0
# Extracted 15 coordinates
# Bounding Box: 4800 4231 20545 10130
# Contour Area: 102974784.0
# Extracted 121 coordinates
# Bounding Box: 50112 2628 12609 10386
# Contour Area: 69751040.0
# Extracted 84 coordinates
# start stitching TCGA-C5-A2LT-01A-01-TSA.6E7DE933-623C-41F5-8007-4EAB8DB691B1
# original size: 72352 x 17181
# downscaled size for stiching: 2261 x 536
# number of patches: 220
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/220 stitched
# progress: 22/220 stitched
# progress: 44/220 stitched
# progress: 66/220 stitched
# progress: 88/220 stitched
# progress: 110/220 stitched
# progress: 132/220 stitched
# progress: 154/220 stitched
# progress: 176/220 stitched
# progress: 198/220 stitched
# segmentation took 0.1358029842376709 seconds
# patching took 0.2733430862426758 seconds
# stitching took 0.07855844497680664 seconds
#
#
# progress: 0.01, 9/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/47a18509-3f63-4f45-8ef1-05d4cd2faaaf/TCGA-IR-A3LF-01Z-00-DX1.ADFB9764-F018-47F5-B6BA-6EFF1079F88E.svs
# ####################################################################################################
# levels: ((119000, 82604), (29750, 20651), (7437, 5162), (3718, 2581))
# mpp: 0.246, base_power: 41x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.25x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-IR-A3LF-01Z-00-DX1.ADFB9764-F018-47F5-B6BA-6EFF1079F88E ...
# Total number of contours to process:  1
# Bounding Box: 4288 1568 111512 77004
# Contour Area: 5973372175.0
# Extracted 5770 coordinates
# start stitching TCGA-IR-A3LF-01Z-00-DX1.ADFB9764-F018-47F5-B6BA-6EFF1079F88E
# original size: 119000 x 82604
# downscaled size for stiching: 3718 x 2581
# number of patches: 5770
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/5770 stitched
# progress: 577/5770 stitched
# progress: 1154/5770 stitched
# progress: 1731/5770 stitched
# progress: 2308/5770 stitched
# progress: 2885/5770 stitched
# progress: 3462/5770 stitched
# progress: 4039/5770 stitched
# progress: 4616/5770 stitched
# progress: 5193/5770 stitched
# segmentation took 1.2657864093780518 seconds
# patching took 0.669790506362915 seconds
# stitching took 1.7176716327667236 seconds
#
#
# progress: 0.02, 10/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/283b1c36-d71a-4e35-beae-fce162a16e14/TCGA-C5-A7X3-01Z-00-DX1.70B9752B-0E55-429A-93E8-E3EE8491DDB5.svs
# ####################################################################################################
# levels: ((136320, 69587), (34080, 17396), (8520, 4349), (2130, 1087))
# mpp: 0.250, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A7X3-01Z-00-DX1.70B9752B-0E55-429A-93E8-E3EE8491DDB5 ...
# Total number of contours to process:  43
# Bounding Box: 111600 65170 4177 2481
# Contour Area: 4498560.0
# Extracted 9 coordinates
# Bounding Box: 131264 63810 5041 4369
# Contour Area: 9776128.0
# Extracted 14 coordinates
# Bounding Box: 54464 59538 6161 5489
# Contour Area: 11022592.0
# Extracted 17 coordinates
# Bounding Box: 35216 59458 4209 2721
# Contour Area: 4371968.0
# Extracted 9 coordinates
# Bounding Box: 79904 57298 4289 2593
# Contour Area: 6358784.0
# Extracted 11 coordinates
# Bounding Box: 119424 57042 7761 12081
# Contour Area: 45063552.0
# Extracted 57 coordinates
# Bounding Box: 87184 54610 6545 6017
# Contour Area: 21612672.0
# Extracted 26 coordinates
# Bounding Box: 128432 54162 5777 8625
# Contour Area: 27089920.0
# Extracted 35 coordinates
# Bounding Box: 111648 53602 6497 8769
# Contour Area: 31337216.0
# Extracted 39 coordinates
# Bounding Box: 81392 52898 5921 5297
# Contour Area: 15964800.0
# Extracted 20 coordinates
# Bounding Box: 120592 52834 4721 5281
# Contour Area: 11052288.0
# Extracted 17 coordinates
# Bounding Box: 52544 50898 5505 9041
# Contour Area: 27806464.0
# Extracted 35 coordinates
# Bounding Box: 85872 50354 6257 5921
# Contour Area: 12837120.0
# Extracted 19 coordinates
# Bounding Box: 2960 49522 4225 2817
# Contour Area: 6353280.0
# Extracted 10 coordinates
# Bounding Box: 35728 49298 6433 8545
# Contour Area: 31161856.0
# Extracted 41 coordinates
# Bounding Box: 43168 48946 7585 16401
# Contour Area: 58428928.0
# Extracted 71 coordinates
# Bounding Box: 106912 47698 3009 3521
# Contour Area: 5603328.0
# Extracted 11 coordinates
# Bounding Box: 114640 47026 6225 3457
# Contour Area: 10978432.0
# Extracted 15 coordinates
# Bounding Box: 4960 46145 5793 4834
# Contour Area: 16153416.0
# Extracted 22 coordinates
# Bounding Box: 9712 43761 6097 5746
# Contour Area: 13630624.0
# Extracted 20 coordinates
# Bounding Box: 39696 43025 5185 2977
# Contour Area: 9602176.0
# Extracted 12 coordinates
# Bounding Box: 124576 42721 9249 11522
# Contour Area: 60716200.0
# Extracted 75 coordinates
# Bounding Box: 31024 42033 3025 3457
# Contour Area: 5594112.0
# Extracted 9 coordinates
# Bounding Box: 109840 41537 3841 5586
# Contour Area: 9690368.0
# Extracted 18 coordinates
# Bounding Box: 49408 39297 9473 11906
# Contour Area: 63129968.0
# Extracted 75 coordinates
# Bounding Box: 78832 37681 18449 15362
# Contour Area: 156421624.0
# Extracted 171 coordinates
# Bounding Box: 92192 36305 22017 27410
# Contour Area: 160778256.0
# Extracted 192 coordinates
# Bounding Box: 112816 35297 7537 7569
# Contour Area: 24447744.0
# Extracted 33 coordinates
# Bounding Box: 39520 32657 5905 6721
# Contour Area: 22639360.0
# Extracted 30 coordinates
# Bounding Box: 2352 31617 19313 14289
# Contour Area: 161616384.0
# Extracted 176 coordinates
# Bounding Box: 10416 31473 28945 26178
# Contour Area: 196557720.0
# Extracted 233 coordinates
# Bounding Box: 123984 29009 2849 2497
# Contour Area: 4420736.0
# Extracted 8 coordinates
# Bounding Box: 48720 27425 2977 2353
# Contour Area: 4428416.0
# Extracted 6 coordinates
# Bounding Box: 100688 14368 3185 5665
# Contour Area: 5641600.0
# Extracted 11 coordinates
# Bounding Box: 95136 10432 27409 23394
# Contour Area: 241902128.0
# Extracted 270 coordinates
# Bounding Box: 98672 9696 2801 4113
# Contour Area: 4743552.0
# Extracted 8 coordinates
# Bounding Box: 112464 9248 4257 3233
# Contour Area: 6251008.0
# Extracted 9 coordinates
# Bounding Box: 27408 9152 3617 5313
# Contour Area: 7101440.0
# Extracted 12 coordinates
# Bounding Box: 109248 6320 2625 4417
# Contour Area: 4628736.0
# Extracted 8 coordinates
# Bounding Box: 21232 5488 28049 22722
# Contour Area: 267265288.0
# Extracted 283 coordinates
# Bounding Box: 37424 1888 2113 4673
# Contour Area: 4822144.0
# Extracted 8 coordinates
# Bounding Box: 46112 1408 8625 3697
# Contour Area: 16834944.0
# Extracted 23 coordinates
# Bounding Box: 117024 208 5729 7137
# Contour Area: 16949888.0
# Extracted 23 coordinates
# start stitching TCGA-C5-A7X3-01Z-00-DX1.70B9752B-0E55-429A-93E8-E3EE8491DDB5
# original size: 136320 x 69587
# downscaled size for stiching: 8520 x 4349
# number of patches: 2191
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 64x64
# progress: 0/2191 stitched
# progress: 220/2191 stitched
# progress: 440/2191 stitched
# progress: 660/2191 stitched
# progress: 880/2191 stitched
# progress: 1100/2191 stitched
# progress: 1320/2191 stitched
# progress: 1540/2191 stitched
# progress: 1760/2191 stitched
# progress: 1980/2191 stitched
# segmentation took 8.382418870925903 seconds
# patching took 4.619288682937622 seconds
# stitching took 3.737051010131836 seconds
#
#
# progress: 0.02, 11/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/763e73b3-a9e4-47b3-a1f1-d2d6e5a82b3a/TCGA-MA-AA3Y-01Z-00-DX1.4540E042-94A5-4D83-8349-96457E8BEE27.svs
# ####################################################################################################
# levels: ((107568, 79550), (26892, 19887), (6723, 4971), (3361, 2485))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-MA-AA3Y-01Z-00-DX1.4540E042-94A5-4D83-8349-96457E8BEE27 ...
# Total number of contours to process:  2
# Bounding Box: 2656 21288 55945 54997
# Contour Area: 1532395700.0
# Extracted 1528 coordinates
# Bounding Box: 64425 3617 39399 75069
# Contour Area: 1893243696.5
# Extracted 1860 coordinates
# start stitching TCGA-MA-AA3Y-01Z-00-DX1.4540E042-94A5-4D83-8349-96457E8BEE27
# original size: 107568 x 79550
# downscaled size for stiching: 3361 x 2485
# number of patches: 3388
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/3388 stitched
# progress: 339/3388 stitched
# progress: 678/3388 stitched
# progress: 1017/3388 stitched
# progress: 1356/3388 stitched
# progress: 1695/3388 stitched
# progress: 2034/3388 stitched
# progress: 2373/3388 stitched
# progress: 2712/3388 stitched
# progress: 3051/3388 stitched
# segmentation took 1.401202917098999 seconds
# patching took 0.4727473258972168 seconds
# stitching took 0.9748191833496094 seconds
#
#
# progress: 0.02, 12/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/ce8c8ff7-24f7-48d9-960d-cf5a48413150/TCGA-EK-A2R7-01A-01-TS1.5C28740A-66C5-4A8A-B0C3-813B0AAFD2EC.svs
# ####################################################################################################
# levels: ((87583, 26145), (21895, 6536), (5473, 1634), (2736, 817))
# mpp: 0.248, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-EK-A2R7-01A-01-TS1.5C28740A-66C5-4A8A-B0C3-813B0AAFD2EC ...
# Total number of contours to process:  2
# Bounding Box: 60341 7424 25802 12865
# Contour Area: 239237808.0
# Extracted 250 coordinates
# Bounding Box: 3201 3392 25962 14017
# Contour Area: 255584272.0
# Extracted 265 coordinates
# start stitching TCGA-EK-A2R7-01A-01-TS1.5C28740A-66C5-4A8A-B0C3-813B0AAFD2EC
# original size: 87583 x 26145
# downscaled size for stiching: 2736 x 817
# number of patches: 515
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/515 stitched
# progress: 52/515 stitched
# progress: 104/515 stitched
# progress: 156/515 stitched
# progress: 208/515 stitched
# progress: 260/515 stitched
# progress: 312/515 stitched
# progress: 364/515 stitched
# progress: 416/515 stitched
# progress: 468/515 stitched
# segmentation took 0.250244140625 seconds
# patching took 0.2153186798095703 seconds
# stitching took 0.1572248935699463 seconds
#
#
# progress: 0.02, 13/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/837cb893-321f-45b8-a600-cff5e6a342a8/TCGA-C5-A8XI-01Z-00-DX1.7E8E0C2A-D3D4-4DCA-9B4E-70A8EBC48E67.svs
# ####################################################################################################
# levels: ((139200, 62985), (34800, 15746), (8700, 3936), (2175, 984))
# mpp: 0.250, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A8XI-01Z-00-DX1.7E8E0C2A-D3D4-4DCA-9B4E-70A8EBC48E67 ...
# Total number of contours to process:  23
# Bounding Box: 33296 45414 7137 4882
# Contour Area: 12439864.0
# Extracted 20 coordinates
# Bounding Box: 16992 45222 12465 9602
# Contour Area: 57539800.0
# Extracted 75 coordinates
# Bounding Box: 2576 43798 8737 18003
# Contour Area: 58084592.0
# Extracted 76 coordinates
# Bounding Box: 88688 41333 9713 17652
# Contour Area: 77654264.0
# Extracted 94 coordinates
# Bounding Box: 103280 40309 11553 10083
# Contour Area: 56610784.0
# Extracted 73 coordinates
# Bounding Box: 118992 39557 6513 5186
# Contour Area: 11917688.0
# Extracted 16 coordinates
# Bounding Box: 44320 26595 7281 20564
# Contour Area: 50760112.0
# Extracted 75 coordinates
# Bounding Box: 24496 26035 19457 13747
# Contour Area: 143999504.0
# Extracted 161 coordinates
# Bounding Box: 8656 25523 17297 21764
# Contour Area: 175992368.0
# Extracted 201 coordinates
# Bounding Box: 93312 21683 17489 21812
# Contour Area: 175182592.0
# Extracted 197 coordinates
# Bounding Box: 50640 20418 4241 2466
# Contour Area: 5890704.0
# Extracted 9 coordinates
# Bounding Box: 108752 19986 18641 14627
# Contour Area: 141399272.0
# Extracted 160 coordinates
# Bounding Box: 128864 19634 6321 21028
# Contour Area: 69562904.0
# Extracted 87 coordinates
# Bounding Box: 104352 18962 5201 3186
# Contour Area: 4267344.0
# Extracted 8 coordinates
# Bounding Box: 21968 18018 4705 5170
# Contour Area: 19171976.0
# Extracted 24 coordinates
# Bounding Box: 27120 14226 7553 3137
# Contour Area: 7677824.0
# Extracted 14 coordinates
# Bounding Box: 133024 13105 4161 2594
# Contour Area: 5696736.0
# Extracted 9 coordinates
# Bounding Box: 87840 12769 14337 13779
# Contour Area: 84389320.0
# Extracted 92 coordinates
# Bounding Box: 3664 11809 15969 17700
# Contour Area: 97469968.0
# Extracted 116 coordinates
# Bounding Box: 17712 10817 4753 5346
# Contour Area: 15510624.0
# Extracted 20 coordinates
# Bounding Box: 95904 7969 5585 4897
# Contour Area: 10122496.0
# Extracted 17 coordinates
# Bounding Box: 22512 5296 8097 12627
# Contour Area: 36354400.0
# Extracted 47 coordinates
# Bounding Box: 100496 352 19377 19875
# Contour Area: 174944024.0
# Extracted 197 coordinates
# start stitching TCGA-C5-A8XI-01Z-00-DX1.7E8E0C2A-D3D4-4DCA-9B4E-70A8EBC48E67
# original size: 139200 x 62985
# downscaled size for stiching: 8700 x 3936
# number of patches: 1788
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 64x64
# progress: 0/1788 stitched
# progress: 179/1788 stitched
# progress: 358/1788 stitched
# progress: 537/1788 stitched
# progress: 716/1788 stitched
# progress: 895/1788 stitched
# progress: 1074/1788 stitched
# progress: 1253/1788 stitched
# progress: 1432/1788 stitched
# progress: 1611/1788 stitched
# segmentation took 6.8428051471710205 seconds
# patching took 2.2363643646240234 seconds
# stitching took 3.2364180088043213 seconds
#
#
# progress: 0.02, 14/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/fb7af9d4-917a-4b05-8506-0b1f8ffd6288/TCGA-C5-A1BL-01Z-00-DX1.E71D7185-85C2-4E08-AA56-006B08FBD630.svs
# ####################################################################################################
# levels: ((49800, 53061), (12450, 13265), (3112, 3316), (1556, 1658))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A1BL-01Z-00-DX1.E71D7185-85C2-4E08-AA56-006B08FBD630 ...
# Total number of contours to process:  6
# Bounding Box: 9185 45860 13475 6529
# Contour Area: 40160144.0
# Extracted 51 coordinates
# Bounding Box: 31141 32355 5409 5921
# Contour Area: 10593280.0
# Extracted 17 coordinates
# Bounding Box: 36677 28802 6786 6306
# Contour Area: 13111264.0
# Extracted 18 coordinates
# Bounding Box: 5472 20897 24197 23716
# Contour Area: 198762275.0
# Extracted 224 coordinates
# Bounding Box: 23075 16609 5666 2721
# Contour Area: 5661760.0
# Extracted 13 coordinates
# Bounding Box: 21891 10496 11939 17379
# Contour Area: 30600465.0
# Extracted 59 coordinates
# start stitching TCGA-C5-A1BL-01Z-00-DX1.E71D7185-85C2-4E08-AA56-006B08FBD630
# original size: 49800 x 53061
# downscaled size for stiching: 1556 x 1658
# number of patches: 382
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/382 stitched
# progress: 39/382 stitched
# progress: 78/382 stitched
# progress: 117/382 stitched
# progress: 156/382 stitched
# progress: 195/382 stitched
# progress: 234/382 stitched
# progress: 273/382 stitched
# progress: 312/382 stitched
# progress: 351/382 stitched
# segmentation took 0.26542186737060547 seconds
# patching took 0.6569538116455078 seconds
# stitching took 0.13753986358642578 seconds
#
#
# progress: 0.02, 15/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/6ca6ba55-e2c9-4f60-b133-b898eadd9d40/TCGA-VS-A958-01A-01-TS1.4B7B9A57-E7DE-4716-8CC7-1901B8DBDC0F.svs
# ####################################################################################################
# levels: ((117527, 27980), (29381, 6995), (7345, 1748), (3672, 874))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-VS-A958-01A-01-TS1.4B7B9A57-E7DE-4716-8CC7-1901B8DBDC0F ...
# Total number of contours to process:  5
# Bounding Box: 17635 17895 6114 2562
# Contour Area: 7418801.0
# Extracted 11 coordinates
# Bounding Box: 8769 16551 2658 3394
# Contour Area: 4525857.0
# Extracted 7 coordinates
# Bounding Box: 67277 11717 4290 4835
# Contour Area: 8776720.0
# Extracted 13 coordinates
# Bounding Box: 10530 6594 38888 12871
# Contour Area: 298879561.0
# Extracted 315 coordinates
# Bounding Box: 72910 1696 41097 14311
# Contour Area: 334654608.0
# Extracted 352 coordinates
# start stitching TCGA-VS-A958-01A-01-TS1.4B7B9A57-E7DE-4716-8CC7-1901B8DBDC0F
# original size: 117527 x 27980
# downscaled size for stiching: 3672 x 874
# number of patches: 698
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/698 stitched
# progress: 70/698 stitched
# progress: 140/698 stitched
# progress: 210/698 stitched
# progress: 280/698 stitched
# progress: 350/698 stitched
# progress: 420/698 stitched
# progress: 490/698 stitched
# progress: 560/698 stitched
# progress: 630/698 stitched
# segmentation took 0.33687710762023926 seconds
# patching took 0.5036334991455078 seconds
# stitching took 0.22508502006530762 seconds
#
#
# progress: 0.03, 16/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/a70ac769-3c69-4d8e-96d8-210e0dbec89c/TCGA-C5-A901-01A-01-TS1.27FDA5E0-E09F-4688-A36F-665532E93D58.svs
# ####################################################################################################
# levels: ((193223, 57064), (48305, 14266), (12076, 3566), (3019, 891))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A901-01A-01-TS1.27FDA5E0-E09F-4688-A36F-665532E93D58 ...
# Total number of contours to process:  9
# Bounding Box: 19024 52679 7457 4369
# Contour Area: 10054144.0
# Extracted 16 coordinates
# Bounding Box: 143701 52231 7953 2097
# Contour Area: 6979072.0
# Extracted 10 coordinates
# Bounding Box: 52081 36021 11458 17731
# Contour Area: 149720546.0
# Extracted 152 coordinates
# Bounding Box: 110211 35204 9506 17764
# Contour Area: 114613352.0
# Extracted 120 coordinates
# Bounding Box: 170630 33396 14673 17604
# Contour Area: 181110592.0
# Extracted 190 coordinates
# Bounding Box: 2848 17010 11985 6322
# Contour Area: 34437136.0
# Extracted 45 coordinates
# Bounding Box: 22752 3456 39539 36950
# Contour Area: 675891862.0
# Extracted 699 coordinates
# Bounding Box: 82146 2064 39219 36166
# Contour Area: 635100083.0
# Extracted 654 coordinates
# Bounding Box: 134116 1120 44179 36486
# Contour Area: 736281612.0
# Extracted 723 coordinates
# start stitching TCGA-C5-A901-01A-01-TS1.27FDA5E0-E09F-4688-A36F-665532E93D58
# original size: 193223 x 57064
# downscaled size for stiching: 12076 x 3566
# number of patches: 2609
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 64x64
# progress: 0/2609 stitched
# progress: 261/2609 stitched
# progress: 522/2609 stitched
# progress: 783/2609 stitched
# progress: 1044/2609 stitched
# progress: 1305/2609 stitched
# progress: 1566/2609 stitched
# progress: 1827/2609 stitched
# progress: 2088/2609 stitched
# progress: 2349/2609 stitched
# segmentation took 8.492146253585815 seconds
# patching took 1.0891120433807373 seconds
# stitching took 3.1089038848876953 seconds
#
#
# progress: 0.03, 17/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/3d4cad79-b9fd-4ffd-abd4-6e16ae0bc3f6/TCGA-IR-A3LK-01A-01-TS1.32ADC40A-C10C-42CB-A014-C41CE398342E.svs
# ####################################################################################################
# levels: ((120903, 37196), (30225, 9299), (7556, 2324), (3778, 1162))
# mpp: 0.248, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-IR-A3LK-01A-01-TS1.32ADC40A-C10C-42CB-A014-C41CE398342E ...
# Total number of contours to process:  2
# Bounding Box: 81732 4353 29763 27498
# Contour Area: 418259050.0
# Extracted 438 coordinates
# Bounding Box: 5152 1888 30691 26570
# Contour Area: 313701526.0
# Extracted 395 coordinates
# start stitching TCGA-IR-A3LK-01A-01-TS1.32ADC40A-C10C-42CB-A014-C41CE398342E
# original size: 120903 x 37196
# downscaled size for stiching: 3778 x 1162
# number of patches: 833
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/833 stitched
# progress: 84/833 stitched
# progress: 168/833 stitched
# progress: 252/833 stitched
# progress: 336/833 stitched
# progress: 420/833 stitched
# progress: 504/833 stitched
# progress: 588/833 stitched
# progress: 672/833 stitched
# progress: 756/833 stitched
# segmentation took 0.42084383964538574 seconds
# patching took 0.31465983390808105 seconds
# stitching took 0.26973724365234375 seconds
#
#
# progress: 0.03, 18/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/06e711e9-5a15-4e59-a293-61ad75558d51/TCGA-EK-A2RL-01A-01-TS1.F2CD492A-F4D7-4939-BFBC-25CA2ED7868B.svs
# ####################################################################################################
# levels: ((71399, 24143), (17849, 6035), (4462, 1508), (2231, 754))
# mpp: 0.248, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-EK-A2RL-01A-01-TS1.F2CD492A-F4D7-4939-BFBC-25CA2ED7868B ...
# Total number of contours to process:  4
# Bounding Box: 63238 10118 4417 5028
# Contour Area: 12209392.0
# Extracted 15 coordinates
# Bounding Box: 18113 7364 3970 4356
# Contour Area: 9064018.0
# Extracted 13 coordinates
# Bounding Box: 46276 4674 20099 13962
# Contour Area: 180188796.0
# Extracted 201 coordinates
# Bounding Box: 2240 1921 18403 14602
# Contour Area: 163930809.0
# Extracted 186 coordinates
# start stitching TCGA-EK-A2RL-01A-01-TS1.F2CD492A-F4D7-4939-BFBC-25CA2ED7868B
# original size: 71399 x 24143
# downscaled size for stiching: 2231 x 754
# number of patches: 415
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/415 stitched
# progress: 42/415 stitched
# progress: 84/415 stitched
# progress: 126/415 stitched
# progress: 168/415 stitched
# progress: 210/415 stitched
# progress: 252/415 stitched
# progress: 294/415 stitched
# progress: 336/415 stitched
# progress: 378/415 stitched
# segmentation took 0.18618297576904297 seconds
# patching took 0.42340970039367676 seconds
# stitching took 0.12514948844909668 seconds
#
#
# progress: 0.03, 19/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/0fbcb861-74eb-4179-bcf3-5826404ebef3/TCGA-VS-A9V1-01Z-00-DX1.BEA16277-7AE1-4149-90BA-E4FDAEF4235F.svs
# ####################################################################################################
# levels: ((43823, 33935), (10955, 8483), (2738, 2120))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-VS-A9V1-01Z-00-DX1.BEA16277-7AE1-4149-90BA-E4FDAEF4235F ...
# Total number of contours to process:  9
# Bounding Box: 20326 23882 4931 4627
# Contour Area: 11441482.0
# Extracted 17 coordinates
# Bounding Box: 25560 20489 4531 5123
# Contour Area: 12647770.5
# Extracted 18 coordinates
# Bounding Box: 14805 17031 10852 8389
# Contour Area: 43564895.0
# Extracted 50 coordinates
# Bounding Box: 13764 10564 2962 3587
# Contour Area: 5677097.0
# Extracted 10 coordinates
# Bounding Box: 31866 6947 3042 5571
# Contour Area: 7389416.0
# Extracted 12 coordinates
# Bounding Box: 26809 6018 5218 5091
# Contour Area: 11189345.0
# Extracted 16 coordinates
# Bounding Box: 16325 5522 7268 7044
# Contour Area: 32655846.0
# Extracted 38 coordinates
# Bounding Box: 36220 5010 2658 3714
# Contour Area: 5771377.0
# Extracted 11 coordinates
# Bounding Box: 11219 3777 2418 4259
# Contour Area: 4905241.0
# Extracted 5 coordinates
# start stitching TCGA-VS-A9V1-01Z-00-DX1.BEA16277-7AE1-4149-90BA-E4FDAEF4235F
# original size: 43823 x 33935
# downscaled size for stiching: 2738 x 2120
# number of patches: 177
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 64x64
# progress: 0/177 stitched
# progress: 18/177 stitched
# progress: 36/177 stitched
# progress: 54/177 stitched
# progress: 72/177 stitched
# progress: 90/177 stitched
# progress: 108/177 stitched
# progress: 126/177 stitched
# progress: 144/177 stitched
# progress: 162/177 stitched
# segmentation took 0.5216503143310547 seconds
# patching took 0.8144016265869141 seconds
# stitching took 0.207472562789917 seconds
#
#
# progress: 0.03, 20/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/c466d87c-cc1a-4ccc-b29c-674e89da5063/TCGA-UC-A7PD-01Z-00-DX1.D4DDF9DF-57A5-4412-95F4-3747579B8DC1.svs
# ####################################################################################################
# levels: ((125496, 76851), (31374, 19212), (7843, 4803), (3921, 2401))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-UC-A7PD-01Z-00-DX1.D4DDF9DF-57A5-4412-95F4-3747579B8DC1 ...
# Total number of contours to process:  6
# Bounding Box: 95474 65712 11363 8035
# Contour Area: 31263281.0
# Extracted 39 coordinates
# Bounding Box: 63564 62639 9378 3362
# Contour Area: 12817664.0
# Extracted 19 coordinates
# Bounding Box: 29381 20869 6914 5346
# Contour Area: 12284576.0
# Extracted 18 coordinates
# Bounding Box: 20643 17124 8899 6722
# Contour Area: 12299873.0
# Extracted 18 coordinates
# Bounding Box: 30085 16516 5474 3906
# Contour Area: 13101040.5
# Extracted 17 coordinates
# Bounding Box: 8321 4257 113271 63056
# Contour Area: 4508146052.0
# Extracted 4482 coordinates
# start stitching TCGA-UC-A7PD-01Z-00-DX1.D4DDF9DF-57A5-4412-95F4-3747579B8DC1
# original size: 125496 x 76851
# downscaled size for stiching: 3921 x 2401
# number of patches: 4593
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/4593 stitched
# progress: 460/4593 stitched
# progress: 920/4593 stitched
# progress: 1380/4593 stitched
# progress: 1840/4593 stitched
# progress: 2300/4593 stitched
# progress: 2760/4593 stitched
# progress: 3220/4593 stitched
# progress: 3680/4593 stitched
# progress: 4140/4593 stitched
# segmentation took 1.2240841388702393 seconds
# patching took 0.9656128883361816 seconds
# stitching took 1.3852617740631104 seconds
#
#
# progress: 0.03, 21/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/92333ba0-aba2-481e-b0d4-2a25a308add8/TCGA-JX-A5QV-01Z-00-DX1.90769414-2C5C-4BAA-A432-9FC0A15EEF5A.svs
# ####################################################################################################
# levels: ((169920, 87899), (42480, 21974), (10620, 5493), (2655, 1373))
# mpp: 0.250, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-JX-A5QV-01Z-00-DX1.90769414-2C5C-4BAA-A432-9FC0A15EEF5A ...
# Total number of contours to process:  1
# Bounding Box: 48880 27299 34769 17763
# Contour Area: 391900912.0
# Extracted 398 coordinates
# start stitching TCGA-JX-A5QV-01Z-00-DX1.90769414-2C5C-4BAA-A432-9FC0A15EEF5A
# ...
# patching took 0.5821881294250488 seconds
# stitching took 1.6030683517456055 seconds
#
#
# progress: 0.99, 596/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/25eef4a8-b4c6-487e-a7fa-973d76294e58/TCGA-EK-A2PI-01A-01-TS1.B85EF208-7541-45F3-A5B4-6ACF3A1124A3.svs
# ####################################################################################################
# levels: ((100912, 41642), (25228, 10410), (6307, 2602), (3153, 1301))
# mpp: 0.247, base_power: 41x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.25x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-EK-A2PI-01A-01-TS1.B85EF208-7541-45F3-A5B4-6ACF3A1124A3 ...
# Total number of contours to process:  6
# Bounding Box: 73003 13475 23749 23014
# Contour Area: 231795864.0
# Extracted 272 coordinates
# Bounding Box: 79436 9954 3714 2978
# Contour Area: 5277664.0
# Extracted 9 coordinates
# Bounding Box: 82317 8321 9154 5155
# Contour Area: 27381793.0
# Extracted 34 coordinates
# Bounding Box: 3968 7457 23365 24071
# Contour Area: 347822829.0
# Extracted 331 coordinates
# Bounding Box: 8961 4481 3682 2753
# Contour Area: 6377088.0
# Extracted 9 coordinates
# Bounding Box: 11745 2368 9571 5154
# Contour Area: 30675490.0
# Extracted 37 coordinates
# start stitching TCGA-EK-A2PI-01A-01-TS1.B85EF208-7541-45F3-A5B4-6ACF3A1124A3
# original size: 100912 x 41642
# downscaled size for stiching: 3153 x 1301
# number of patches: 692
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/692 stitched
# progress: 70/692 stitched
# progress: 140/692 stitched
# progress: 210/692 stitched
# progress: 280/692 stitched
# progress: 350/692 stitched
# progress: 420/692 stitched
# progress: 490/692 stitched
# progress: 560/692 stitched
# progress: 630/692 stitched
# segmentation took 0.4185798168182373 seconds
# patching took 0.7587029933929443 seconds
# stitching took 0.2252652645111084 seconds
#
#
# progress: 0.99, 597/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/cdfe2cfc-61c5-49dc-a4be-102ebcb46d07/TCGA-VS-A9V4-01A-01-TS1.AF83B1E4-E46D-4069-B494-166AACA09AE8.svs
# ####################################################################################################
# levels: ((77688, 32217), (19422, 8054), (4855, 2013), (2427, 1006))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-VS-A9V4-01A-01-TS1.AF83B1E4-E46D-4069-B494-166AACA09AE8 ...
# Total number of contours to process:  5
# Bounding Box: 8482 26036 5891 3459
# Contour Area: 6697667.0
# Extracted 12 coordinates
# Bounding Box: 63059 21904 6275 3428
# Contour Area: 9616915.0
# Extracted 13 coordinates
# Bounding Box: 12771 17581 7780 8904
# Contour Area: 26734008.0
# Extracted 39 coordinates
# Bounding Box: 2816 8518 17575 16846
# Contour Area: 115950234.5
# Extracted 135 coordinates
# Bounding Box: 57841 5188 17447 17262
# Contour Area: 182079946.0
# Extracted 189 coordinates
# start stitching TCGA-VS-A9V4-01A-01-TS1.AF83B1E4-E46D-4069-B494-166AACA09AE8
# original size: 77688 x 32217
# downscaled size for stiching: 2427 x 1006
# number of patches: 388
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/388 stitched
# progress: 39/388 stitched
# progress: 78/388 stitched
# progress: 117/388 stitched
# progress: 156/388 stitched
# progress: 195/388 stitched
# progress: 234/388 stitched
# progress: 273/388 stitched
# progress: 312/388 stitched
# progress: 351/388 stitched
# segmentation took 0.24047303199768066 seconds
# patching took 0.5944948196411133 seconds
# stitching took 0.13124680519104004 seconds
#
#
# progress: 0.99, 598/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/e2ac2250-170f-4f2d-a5d0-b73a66acb686/TCGA-C5-A1BL-01A-01-TS1.c800c102-9c54-4715-84f0-76d2e768aead.svs
# ####################################################################################################
# levels: ((75207, 36928), (18801, 9232), (4700, 2308), (2350, 1154))
# mpp: 0.248, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A1BL-01A-01-TS1.c800c102-9c54-4715-84f0-76d2e768aead ...
# Total number of contours to process:  2
# Bounding Box: 41827 9792 21219 15265
# Contour Area: 232221360.0
# Extracted 249 coordinates
# Bounding Box: 5568 9696 23267 14081
# Contour Area: 210202080.0
# Extracted 220 coordinates
# start stitching TCGA-C5-A1BL-01A-01-TS1.c800c102-9c54-4715-84f0-76d2e768aead
# original size: 75207 x 36928
# downscaled size for stiching: 2350 x 1154
# number of patches: 469
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/469 stitched
# progress: 47/469 stitched
# progress: 94/469 stitched
# progress: 141/469 stitched
# progress: 188/469 stitched
# progress: 235/469 stitched
# progress: 282/469 stitched
# progress: 329/469 stitched
# progress: 376/469 stitched
# progress: 423/469 stitched
# segmentation took 0.27318859100341797 seconds
# patching took 0.2556943893432617 seconds
# stitching took 0.15206670761108398 seconds
#
#
# progress: 0.99, 599/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/5bf59557-8e98-4588-9d35-39204a167175/TCGA-EA-A3HT-01A-06-TSF.E0252DEC-7ED8-467F-B719-79F823345EAF.svs
# ####################################################################################################
# levels: ((88536, 34448), (22134, 8612), (5533, 2153), (2766, 1076))
# mpp: 0.247, base_power: 41x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.25x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-EA-A3HT-01A-06-TSF.E0252DEC-7ED8-467F-B719-79F823345EAF ...
# Total number of contours to process:  2
# Bounding Box: 2784 5986 27433 24493
# Contour Area: 395501505.0
# Extracted 397 coordinates
# Bounding Box: 56591 3393 27944 23308
# Contour Area: 427966102.0
# Extracted 426 coordinates
# start stitching TCGA-EA-A3HT-01A-06-TSF.E0252DEC-7ED8-467F-B719-79F823345EAF
# original size: 88536 x 34448
# downscaled size for stiching: 2766 x 1076
# number of patches: 823
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/823 stitched
# progress: 83/823 stitched
# progress: 166/823 stitched
# progress: 249/823 stitched
# progress: 332/823 stitched
# progress: 415/823 stitched
# progress: 498/823 stitched
# progress: 581/823 stitched
# progress: 664/823 stitched
# progress: 747/823 stitched
# segmentation took 0.3182368278503418 seconds
# patching took 0.2742900848388672 seconds
# stitching took 0.24246525764465332 seconds
#
#
# progress: 0.99, 600/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/9ba30dfc-fbe5-4ee8-8664-6a1b50cfe928/TCGA-C5-A7CJ-01A-01-TS1.F5E60902-B807-484C-A3C8-C44C12E7DACD.svs
# ####################################################################################################
# levels: ((101591, 31806), (25397, 7951), (6349, 1987), (3174, 993))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A7CJ-01A-01-TS1.F5E60902-B807-484C-A3C8-C44C12E7DACD ...
# Total number of contours to process:  2
# Bounding Box: 77457 5669 20198 23095
# Contour Area: 246960504.5
# Extracted 262 coordinates
# Bounding Box: 2496 1761 21414 20372
# Contour Area: 231968207.0
# Extracted 240 coordinates
# start stitching TCGA-C5-A7CJ-01A-01-TS1.F5E60902-B807-484C-A3C8-C44C12E7DACD
# original size: 101591 x 31806
# downscaled size for stiching: 3174 x 993
# number of patches: 502
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/502 stitched
# progress: 51/502 stitched
# progress: 102/502 stitched
# progress: 153/502 stitched
# progress: 204/502 stitched
# progress: 255/502 stitched
# progress: 306/502 stitched
# progress: 357/502 stitched
# progress: 408/502 stitched
# progress: 459/502 stitched
# segmentation took 0.3117225170135498 seconds
# patching took 0.2697317600250244 seconds
# stitching took 0.16108393669128418 seconds
#
#
# progress: 1.00, 601/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/288c5d70-e010-47e7-9b92-66ba3b3ac34d/TCGA-DS-A7WI-01A-01-TS1.013BB459-C1BF-4F49-908F-E5EB2DB644A9.svs
# ####################################################################################################
# levels: ((111552, 28266), (27888, 7066), (6972, 1766), (3486, 883))
# mpp: 0.253, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-DS-A7WI-01A-01-TS1.013BB459-C1BF-4F49-908F-E5EB2DB644A9 ...
# Total number of contours to process:  3
# Bounding Box: 105120 23464 4289 3394
# Contour Area: 9572000.0
# Extracted 12 coordinates
# Bounding Box: 71488 7778 32577 18856
# Contour Area: 416731680.0
# Extracted 421 coordinates
# Bounding Box: 2784 3937 34913 22729
# Contour Area: 420035488.0
# Extracted 434 coordinates
# start stitching TCGA-DS-A7WI-01A-01-TS1.013BB459-C1BF-4F49-908F-E5EB2DB644A9
# original size: 111552 x 28266
# downscaled size for stiching: 3486 x 883
# number of patches: 867
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 32x32
# progress: 0/867 stitched
# progress: 87/867 stitched
# progress: 174/867 stitched
# progress: 261/867 stitched
# progress: 348/867 stitched
# progress: 435/867 stitched
# progress: 522/867 stitched
# progress: 609/867 stitched
# progress: 696/867 stitched
# progress: 783/867 stitched
# segmentation took 0.33007025718688965 seconds
# patching took 0.4066650867462158 seconds
# stitching took 0.263812780380249 seconds
#
#
# progress: 1.00, 602/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/28c99d8f-d9e0-42a0-a6ee-8a304b93b83b/TCGA-C5-A3HE-01Z-00-DX1.9792538B-1DA9-41F0-B1F3-5C13B23AA7E0.svs
# ####################################################################################################
# levels: ((159360, 45900), (39840, 11475), (9960, 2868), (2490, 717))
# mpp: 0.250, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-C5-A3HE-01Z-00-DX1.9792538B-1DA9-41F0-B1F3-5C13B23AA7E0 ...
# Total number of contours to process:  24
# Bounding Box: 119936 37449 5489 4146
# Contour Area: 10843992.0
# Extracted 16 coordinates
# Bounding Box: 106144 33656 7521 4979
# Contour Area: 16617392.0
# Extracted 27 coordinates
# Bounding Box: 114544 31512 4385 5954
# Contour Area: 11167112.0
# Extracted 16 coordinates
# Bounding Box: 139376 31240 3617 2801
# Contour Area: 5464448.0
# Extracted 10 coordinates
# Bounding Box: 22304 31128 5569 4194
# Contour Area: 11104568.0
# Extracted 16 coordinates
# Bounding Box: 116032 28743 3809 4690
# Contour Area: 5429784.0
# Extracted 10 coordinates
# Bounding Box: 8496 27239 7665 4978
# Contour Area: 16965984.0
# Extracted 26 coordinates
# Bounding Box: 17104 25158 4305 5971
# Contour Area: 10718848.0
# Extracted 16 coordinates
# Bounding Box: 102688 23142 12017 12372
# Contour Area: 80166568.0
# Extracted 95 coordinates
# Bounding Box: 137152 21925 4433 5571
# Contour Area: 7098352.0
# Extracted 13 coordinates
# Bounding Box: 29536 20629 3777 4930
# Contour Area: 8257416.0
# Extracted 14 coordinates
# Bounding Box: 157008 20517 2241 5298
# Contour Area: 4569424.0
# Extracted 9 coordinates
# Bounding Box: 107552 19317 3169 3906
# Contour Area: 6427760.0
# Extracted 9 coordinates
# Bounding Box: 143328 19189 11265 10611
# Contour Area: 45159040.0
# Extracted 60 coordinates
# Bounding Box: 115632 16916 14977 20102
# Contour Area: 121116872.0
# Extracted 153 coordinates
# Bounding Box: 4464 16676 12913 12404
# Contour Area: 83034952.0
# Extracted 96 coordinates
# Bounding Box: 40432 16052 5009 5442
# Contour Area: 6912184.0
# Extracted 12 coordinates
# Bounding Box: 38992 15604 3537 4706
# Contour Area: 6711600.0
# Extracted 13 coordinates
# Bounding Box: 60704 14419 3185 5379
# Contour Area: 5768728.0
# Extracted 11 coordinates
# Bounding Box: 46816 13315 10353 10548
# Contour Area: 45181624.0
# Extracted 57 coordinates
# Bounding Box: 10352 12819 3121 3954
# Contour Area: 6386272.0
# Extracted 9 coordinates
# Bounding Box: 18320 11042 13041 19446
# Contour Area: 115192584.0
# Extracted 144 coordinates
# Bounding Box: 128784 7794 7777 16581
# Contour Area: 51939184.0
# Extracted 62 coordinates
# Bounding Box: 32048 1744 7713 16645
# Contour Area: 52187160.0
# Extracted 64 coordinates
# start stitching TCGA-C5-A3HE-01Z-00-DX1.9792538B-1DA9-41F0-B1F3-5C13B23AA7E0
# original size: 159360 x 45900
# downscaled size for stiching: 9960 x 2868
# number of patches: 958
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 64x64
# progress: 0/958 stitched
# progress: 96/958 stitched
# progress: 192/958 stitched
# progress: 288/958 stitched
# progress: 384/958 stitched
# progress: 480/958 stitched
# progress: 576/958 stitched
# progress: 672/958 stitched
# progress: 768/958 stitched
# progress: 864/958 stitched
# segmentation took 5.350514888763428 seconds
# patching took 2.6716384887695312 seconds
# stitching took 1.778618335723877 seconds
#
#
# progress: 1.00, 603/604
# processing /datastore/uittogether3/LuuTru/Thanhld/WSI/dataset/CESC/gdc_manifest.2026-04-23.162946/39c1e6be-e703-4de4-a25d-36ea6ffd3722/TCGA-FU-A57G-01Z-00-DX1.3007337B-A044-4831-B957-F8740E9ACB4E.svs
# ####################################################################################################
# levels: ((39329, 37495), (9832, 9373), (2458, 2343))
# mpp: 0.252, base_power: 40x, patch_level: 1, patch_downsample: 4.00, patch_power: 10.00x, profile: 10x, patch_size: 256, step_size: 256
# ####################################################################################################
# Performing segmentation
# Creating patches for:  TCGA-FU-A57G-01Z-00-DX1.3007337B-A044-4831-B957-F8740E9ACB4E ...
# Total number of contours to process:  3
# Bounding Box: 9120 13970 29457 21685
# Contour Area: 439534480.0
# Extracted 447 coordinates
# Bounding Box: 20096 3280 5761 4674
# Contour Area: 14531432.0
# Extracted 21 coordinates
# Bounding Box: 2224 2800 17121 12723
# Contour Area: 135168880.0
# Extracted 149 coordinates
# start stitching TCGA-FU-A57G-01Z-00-DX1.3007337B-A044-4831-B957-F8740E9ACB4E
# original size: 39329 x 37495
# downscaled size for stiching: 2458 x 2343
# number of patches: 617
# patch size: 256x256 patch level: 1
# ref patch size: (1024, 1024)x(1024, 1024)
# downscaled patch size: 64x64
# progress: 0/617 stitched
# progress: 62/617 stitched
# progress: 124/617 stitched
# progress: 186/617 stitched
# progress: 248/617 stitched
# progress: 310/617 stitched
# progress: 372/617 stitched
# progress: 434/617 stitched
# progress: 496/617 stitched
# progress: 558/617 stitched
# segmentation took 0.8561263084411621 seconds
# patching took 0.38117456436157227 seconds
# stitching took 0.5196192264556885 seconds
# average segmentation time in s per slide: 1.3714474514620194
# average patching time in s per slide: 0.7057346788463214
# average stiching time in s per slide: 0.823955201944768

# %% [markdown]
# ### 2.2. Extract features (use vision encoder of TITAN (CONCHv1.5))

# %%
# !mkdir scripts/extract_feature/logs
# Out:
# mkdir: cannot create directory ‘scripts/extract_feature/logs’: File exists

# %%
# Tải checkpoint của CONCHv1.5 (TITAN vision encoder)
# !mkdir /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH/models/ckpts
# %cd /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH/models/ckpts
# !gdown --id 1QmH-dZJ6lr540XGAdZA5-IjkUv8ITHST
# !mv "conch_v1_5_pytorch_model.bin" "conch1.5.bin"
# Out:
# mkdir: cannot create directory ‘/datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH/models/ckpts’: File exists
# /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH/models/ckpts
# /bin/bash: line 1: gdown: command not found
# mv: cannot stat 'conch_v1_5_pytorch_model.bin': No such file or directory

# %%
# Tải checkpoint của CONCHv1.5 từ Hugging Face
# Repo MahmoodLab/conchv1_5 không có config.json cho timm hf_hub,
# nên cần tải trực tiếp file pytorch_model_vision.bin rồi đổi tên thành conch1.5.bin
import os
from getpass import getpass
from pathlib import Path

import shutil
from huggingface_hub import hf_hub_download

ckpt_dir = Path("/datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH/models/ckpts")
ckpt_dir.mkdir(parents=True, exist_ok=True)
ckpt_path = ckpt_dir / "conch1.5.bin"

token = os.environ.get("HF_TOKEN")
if not token:
    token = getpass("Nhập Hugging Face token: ")
token = token.strip()

downloaded = hf_hub_download(
    repo_id="MahmoodLab/conchv1_5",
    filename="pytorch_model_vision.bin",
    token=token,
)
shutil.copy2(downloaded, ckpt_path)
print(f"Saved checkpoint to {ckpt_path}")

# %%
# %cd /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH
# !mkdir csv

TASK_NAME="CESC_feats_conch15"   # Task name, change it as you want

csv_path="csv/" + TASK_NAME
# !mkdir $csv_path

# auto generate csv
# !python scripts/extract_feature/generate_csv.py \
        --h5_dir "./downloaded_data/CESC_patches/patches" \
        --num 1 \
        --root "csv/CESC_feats_conch15"

# !python extract_features_fp_fast.py \
#         --model "conch15" \
#         --csv_path "./csv/CESC_feats_conch15/part_0.csv" \
#         --data_coors_dir "./downloaded_data/CESC_patches" \
#         --data_slide_dir "./downloaded_data/CESC" \
#         --feat_dir "./downloaded_data/CESC_feats_conch15" \
#         --ignore_partial yes \
#         --batch_size 32 \
#         --datatype auto \
#         --slide_ext ".svs" \
#         --save_storage "yes"
# Out:
# /datastore/uittogether3/LuuTru/Thanhld/WSI/MergeSlide_TTA/notebooks/PrePATH
